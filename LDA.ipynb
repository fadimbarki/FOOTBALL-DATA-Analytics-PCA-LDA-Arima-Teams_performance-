# %%
import pandas as pd

df = pd.read_csv (r'C:\Users\HP\football\Erggg.csv')

# %%
df
# Out:
#                  countries  totalgames  total_wins  total_loses  total_x  \
# 0                 Scotland         790         375          246      169
# 1                  England        1020         580          197      243
# 2                    Wales         667         215          309      143
# 3         Northern Ireland         654         166          338      150
# 4            United States         691         299          247      145
# ..                     ...         ...         ...          ...      ...
# 262               Alderney          19           3           16        0
# 263                   Sark           4           0            4        0
# 264          Western Isles          28          11           14        3
# 265                 Kosovo          49          18           21       10
# 266  Republic of St. Pauli           4           1            2        1
#
#      friendly_wins  friendly_loses  friendly_x  no_friendly_wins  \
# 0              102              84          45               273
# 1              227              90          98               353
# 2               49              73          34               166
# 3               30              55          34               136
# 4              130             147          86               169
# ..             ...             ...         ...               ...
# 262              0               0           0                 3
# 263              0               0           0                 0
# 264              0               0           0                11
# 265             10               4           3                 8
# 266              0               0           0                 1
#
#      no_friendly_loses  no_friendly_x  totalgames_2015_2021  \
# 0                  162            124                    53
# 1                  107            145                    72
# 2                  236            109                    58
# 3                  283            116                    59
# 4                  100             59                    83
# ..                 ...            ...                   ...
# 262                 16              0                    11
# 263                  4              0                     0
# 264                 14              3                    12
# 265                 17              7                    44
# 266                  2              1                     0
#
#      total_wins_2015_2021  total_loses_2015_2021  total_x_2015_2021  \
# 0                      24                     20                  9
# 1                      45                     13                 14
# 2                      28                     17                 13
# 3                      22                     23                 14
# 4                      45                     22                 16
# ..                    ...                    ...                ...
# 262                     2                      9                  0
# 263                     0                      0                  0
# 264                     4                      7                  1
# 265                    16                     19                  9
# 266                     0                      0                  0
#
#      total_goals_scored  total_goals_scored_in  total_goals_scored_2015_2021  \
# 0                  1364                    972                            79
# 1                  2230                    999                           146
# 2                   832                   1087                            69
# 3                   680                   1233                            62
# 4                  1020                    918                           166
# ..                  ...                    ...                           ...
# 262                  15                     75                            11
# 263                   0                     70                             0
# 264                  44                     70                            14
# 265                  70                     74                            60
# 266                  10                      5                             0
#
#      total_goals_scored_in_2015_2021                        category
# 0                                 67     Team_with_Fifa_Rank( 1--89)
# 1                                 53     Team_with_Fifa_Rank( 1--89)
# 2                                 49     Team_with_Fifa_Rank( 1--89)
# 3                                 62     Team_with_Fifa_Rank( 1--89)
# 4                                 84     Team_with_Fifa_Rank( 1--89)
# ..                               ...                             ...
# 262                               44  Team_with_Fifa_Rank( 180--269)
# 263                                0  Team_with_Fifa_Rank( 180--269)
# 264                               41  Team_with_Fifa_Rank( 180--269)
# 265                               64   Team_with_Fifa_Rank( 90--179)
# 266                                0  Team_with_Fifa_Rank( 180--269)
#
# [267 rows x 20 columns]

# %%
X = df[['totalgames','total_wins', 'total_loses', 'total_x','friendly_wins', 'friendly_loses', 'friendly_x','no_friendly_wins', 'no_friendly_loses', 'no_friendly_x', 'totalgames_2015_2021', 'total_wins_2015_2021', 'total_loses_2015_2021', 'total_x_2015_2021', 'total_goals_scored', 'total_goals_scored_in', 'total_goals_scored_2015_2021', 'total_goals_scored_in_2015_2021']]

# %%
X
# Out:
#      totalgames  total_wins  total_loses  total_x  friendly_wins  \
# 0           790         375          246      169            102
# 1          1020         580          197      243            227
# 2           667         215          309      143             49
# 3           654         166          338      150             30
# 4           691         299          247      145            130
# ..          ...         ...          ...      ...            ...
# 262          19           3           16        0              0
# 263           4           0            4        0              0
# 264          28          11           14        3              0
# 265          49          18           21       10             10
# 266           4           1            2        1              0
#
#      friendly_loses  friendly_x  no_friendly_wins  no_friendly_loses  \
# 0                84          45               273                162
# 1                90          98               353                107
# 2                73          34               166                236
# 3                55          34               136                283
# 4               147          86               169                100
# ..              ...         ...               ...                ...
# 262               0           0                 3                 16
# 263               0           0                 0                  4
# 264               0           0                11                 14
# 265               4           3                 8                 17
# 266               0           0                 1                  2
#
#      no_friendly_x  totalgames_2015_2021  total_wins_2015_2021  \
# 0              124                    53                    24
# 1              145                    72                    45
# 2              109                    58                    28
# 3              116                    59                    22
# 4               59                    83                    45
# ..             ...                   ...                   ...
# 262              0                    11                     2
# 263              0                     0                     0
# 264              3                    12                     4
# 265              7                    44                    16
# 266              1                     0                     0
#
#      total_loses_2015_2021  total_x_2015_2021  total_goals_scored  \
# 0                       20                  9                1364
# 1                       13                 14                2230
# 2                       17                 13                 832
# 3                       23                 14                 680
# 4                       22                 16                1020
# ..                     ...                ...                 ...
# 262                      9                  0                  15
# 263                      0                  0                   0
# 264                      7                  1                  44
# 265                     19                  9                  70
# 266                      0                  0                  10
#
#      total_goals_scored_in  total_goals_scored_2015_2021  \
# 0                      972                            79
# 1                      999                           146
# 2                     1087                            69
# 3                     1233                            62
# 4                      918                           166
# ..                     ...                           ...
# 262                     75                            11
# 263                     70                             0
# 264                     70                            14
# 265                     74                            60
# 266                      5                             0
#
#      total_goals_scored_in_2015_2021
# 0                                 67
# 1                                 53
# 2                                 49
# 3                                 62
# 4                                 84
# ..                               ...
# 262                               44
# 263                                0
# 264                               41
# 265                               64
# 266                                0
#
# [267 rows x 18 columns]

# %%
le = LabelEncoder()
y = le.fit_transform(df['category'])

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()
X_lda = lda.fit_transform(X, y)

# %%
plt.xlabel('LD1')
plt.ylabel('LD2')
plt.scatter(
    X_lda[:,0],
    X_lda[:,1],
    c=y,
    cmap='rainbow',
    alpha=0.7,
    edgecolors='b'
)

# %%
print(lda.scalings_)
# Out:
# [[-3.9049e-05 -2.5733e-03]
#  [ 1.6124e-03 -1.1613e-02]
#  [-3.4219e-03  4.2737e-03]
#  [-1.8472e-05 -1.1373e-03]
#  [ 3.5286e-03 -1.7859e-02]
#  [-6.7120e-03  2.7422e-03]
#  [-1.1124e-03 -2.2044e-02]
#  [ 2.3557e-03 -2.2021e-02]
#  [-3.9027e-03  8.3208e-03]
#  [ 8.9051e-04  1.5283e-02]
#  [-3.3744e-02  1.9377e-02]
#  [-6.1957e-02 -7.9862e-02]
#  [-5.2468e-02  1.1916e-01]
#  [ 2.8749e-03  3.4019e-02]
#  [-1.4667e-03  9.7769e-03]
#  [ 1.8877e-03 -3.7723e-03]
#  [-4.9373e-03  1.9100e-02]
#  [ 1.5455e-02 -1.8813e-02]]
